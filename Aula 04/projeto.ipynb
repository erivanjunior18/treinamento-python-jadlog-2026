# %% [markdown]
# Importando bibliotecas

# %%
# !pip install pywhatkit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached PyAutoGUI-0.9.54.tar.gz (61 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached pytweening-1.2.0.tar.gz (171 kB)
# ...

# %%
import os
import smtplib
import shutil
import pyautogui
import pywhatkit as kit
import win32com.client as win32
from time import sleep
from datetime import datetime
from email.message import EmailMessage
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import smtplib
#       3 import shutil
# ----> 4 import pyautogui
#       5 import pywhatkit as kit
#       6 import win32com.client as win32
#
# ModuleNotFoundError: No module named 'pyautogui'

# %% [markdown]
# Organizando arquivos

# %%
arquivo_excel = 'contas_processadas.xlsx'
pasta_base = 'base'


# Criando a pasta base dentro da pasta Aula 04

# %% [markdown]
# Verificando se o arquivo existe

# %%
if not os.path.exists(arquivo_excel):
    raise FileNotFoundError('Arquivo não encontrado, verifique se o download está concluído.')

print("Arquivo encontrado")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 if not os.path.exists(arquivo_excel):
# ----> 2     raise FileNotFoundError('Arquivo não encontrado, verifique se o download está concluído.')
#       4 print("Arquivo encontrado")
#
# FileNotFoundError: Arquivo não encontrado, verifique se o download está concluído.

# %% [markdown]
# Criando a pasta base dentro da pasta Aula 04

# %%
if not os.path.exists(pasta_base):
    os.makedirs(pasta_base)
    print('Pasta criada com sucesso.')

else:
    print('Pasta base já foi existe.')
# Out:
# Pasta base já foi existe.

# %% [markdown]
# Movendo arquivo para dentro da pasta Base

# %%
destino = os.path.join(pasta_base, os.path.basename(arquivo_excel))

if not os.path.exists(destino):
    shutil.move(arquivo_excel,destino)
    print('Arquivo movido com sucesso!')

else:
    print('Arquivo já existe na pasta Base')
# Out:
# Arquivo movido com sucesso!

# %% [markdown]
# Criando corpo do E-mail

# %%
hoje = datetime.now().strftime('%d . %m . %Y | %H:%M')

corpo_email = f"""
Prezados,

Segue em anexo o relatorio de contas processas do mês de janeiro.
Data de processamento: {hoje}

Atenciosamente, 
"""

# %% [markdown]
# Configurando Outlook

# %%
pythoncom.CoInitialize()

outlook = win32.Dispatch('Outlook.Application')

email = outlook.CreateItem(0)

email.To = 'erivan.junior@jadlog.com.br'
email.Subject = 'Relatorio de contas processadas de janeiro'
email.Body = corpo_email

email.Attachments.Add(
    r'C:\Users\erivan.junior\OneDrive - JADLOG LOGISTICA LTDA\C_Python\Aula 04\base\contas_processadas.xlsx'
)

email.Send()

print('E-mail enviado com sucesso')

# %% [markdown]
# Alerta WhatsApp

# %%
telefone = '+5511988277472'

mensagem = 'Relatório enviado ciclano!!'

kit.sendwhatmsg_instantly(
    telefone,
    mensagem,
    wait_time=20,
    tab_close=False
)

sleep(2)

pyautogui.press('enter')
print('Mensagem enviada pelo WhatsApp com sucesso!')

# %% [markdown]
# Criando executável

# %%
#!pip install pyinstaller

#jupyter nbconvert --to script projeto.ipynb

# !pyinstaller --onefile projeto.py
# Out:
# 'pyinstaller' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.
